# %% [markdown]
# # Traffic_Demand_LightGBM_CatBoost
# Traffic demand prediction pipeline with feature engineering, geohash decoding, CV training, and ensemble.

# %%
# Load train.csv and test.csv
import pandas as pd
import numpy as np

# %%
# Decode geohash and create time/location features
# (adapt from original notebook)

# %%
# Preprocess categorical and numeric columns

# %%
# Models
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor

lgbm = LGBMRegressor(n_estimators=3000, learning_rate=0.03)
cat = CatBoostRegressor(iterations=3000, learning_rate=0.03, verbose=False)
# Blend predictions

# %%
# Train with KFold CV, generate predictions, save submission.csv
